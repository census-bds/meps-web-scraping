# %% [markdown]
# ## Fix duplicate start links
#
# Sometimes we got the same start_url from Google for multiple government units and it's clearly incorrect (e.g. Baltimore County vs. Baltimore city). This notebook facilitates a semi-manual fix.

# %%
import pandas as pd
import sqlite3

pd.set_option('display.max_rows', 50)

# %%
dbconn = sqlite3.connect("sbc_db_2022.sqlite")

# %%
gov_info =  pd.read_sql("SELECT * FROM gov_info WHERE sbc_count>0;", dbconn)

# %%
gov_info.shape
# Out:
# (216, 21)

# %%
gov_info.drop_duplicates(subset=['start_url']).shape
# Out:
# (197, 21)

# %%
dup_counts = gov_info.groupby('start_url').count().reset_index()[['start_url', 'ID',]]
url_dup_counts = gov_info[['id_idcd_plant', 'MNAME', 'start_url']].merge(dup_counts, how='left', on='start_url')
url_dup_counts.sort_values(by=['ID', 'start_url',], ascending=False).head(50)
# Out:
#       id_idcd_plant                                              MNAME  \
# 177  43107907900000                                     SHELBY COUNTY
# 178  43107907900100  SHELBY COUNTY HEALTH CARE CORPORATION- PERSONN...
# 181  43207900501000   MEMPHIS AND SHELBY COUNTY CENTER CITY COMMISSION
# 23   05100700700000                               CONTRA COSTA COUNTY
# 24   05100700704700                    CONTRA COSTA HOUSING AUTHORITY
# 26   05100700730100               CONTRA COSTA COUNTY SPECIAL SCHOOLS
# 17   04000000004105                                     SYSTEM OFFICE
# 182  44000000017301    UNIVERSITY OF TEXAS OFFICE OF EMPLOYEE BENEFITS
# 117  26000000003900                     SOUTHEAST MISSOURI STATE UNIV
# 118  26000000004000                         MISSOURI STATE UNIVERSITY
# 139  34103403400000                     FORSYTH COUNTY HUMAN RESOURCES
# 140  34103403430200                         FORSYTH TECHNICAL COLLEGE
# 42   06501600100000                          DENVER SCHOOL DISTRICT 1
# 43   06501850100000                          DOUGLAS CO SCH DIST RE 1
# 137  34103203200000                                     DURHAM COUNTY
# 138  34103203200400              DURHAM CONVENTION AND VISITORS BUREAU
# 63   14101601600000                                       COOK COUNTY
# 64   14101601600200              COOK COUNTY FOREST PRESERVE DISTRICT
# 65   14201601600000                                   CITY OF CHICAGO
# 66   14501615800000               CITY OF CHICAGO SCHOOL DISTRICT 299
# 158  36202500300000                                     COLUMBUS CITY
# 160  36502500300000                           COLUMBUS PUBLIC SCHOOLS
# 28   05101901905700   LOS ANGELES CO LOCAL AGENCY FORMATION COMMISSION
# 33   05105405301100        TULARE CO LOCAL AGENCY FORMATION COMMISSION
# 20   05000000000000                        STATE OF CALIFORNIA CALPERS
# 30   05103303330100                  RIVERSIDE COUNTY SPECIAL SCHOOLS
# 175  43106306300000                                 MONTGOMERY COUNTY
# 176  43106306330100                            MONTGOMERY CO SCH DIST
# 81   18205601400300                     LOUISVILLE CITY WATER COMPANY
# 82   18205601400800  LOUISVILLE-JEFF COUNTY REGIONAL AIRPORT AUTHORITY
# 80   18205601400000  LOUISVILLE-JEFFERSON COUNTY METRO GOVT- HUMAN ...
# 83   18205601401300  LOUISVILLE AND JEFFERSON CO CONVENTION AND VIS...
# 142  36000000000000                                     STATE OF OHIO
# 148  36000000007800                             OHIO STATE UNIVERSITY
# 10   02000000030600  BERING STRAIT REAA ST OF AK - DEPT OF ADMIN  D...
# 12   02000000031200  LOWER YUKON REAA ST OF AK - DEPT OF ADMIN  DIV...
# 100                 https://www.wsscwater.com/benefits   1
# 154    https://www.wright.edu/human-resources/benefits   1
# 123                 https://www.washoeschools.net/risk   1
# 71   https://www.vinu.edu/web/human-resources/medic...   1
# 57   https://www.vcsedu.org/directory/departments/h...   1
# 209  https://www.vbgov.com/Site-Info/employees/bene...   1
# 183  https://www.utsystem.edu/offices/employee-bene...   1
# 153          https://www.utoledo.edu/depts/hr/benefits   1
# 75             https://www.usd259.org/employeebenefits   1

# %% [markdown]
# ### Fix a specified ID

# %%
# get the next url from the google queries
id_to_fix = gov_info.loc[gov_info['MNAME'] == 'DENVER SCHOOL DISTRICT 1 ']['id_idcd_plant'].values[0]

# %%
google_urls = pd.read_sql("SELECT * FROM google_query_results WHERE id_idcd_plant=?", dbconn, params=(id_to_fix,))

# %%
google_urls
# Out:
#    url_index                                          start_url  \
# 0          1  https://www.dcsdk12.org/about/our_district/dep...
# 1          2             http://thecommons.dpsk12.org/Page/1397
# 2          3  https://www.denverhealth.org/-/media/files/emp...
# 3          4  https://www.cu.edu/employee-services/benefits-...
# 4          5  https://dhr.colorado.gov/state-employees/state...
# 5          6                            https://www.dpsk12.org/
# 6          7      https://careers.dpsk12.org/teach/teachercomp/
# 7          8      https://www.landerschools.org/Human-Resources
# 8          9  https://www.jeffcopublicschools.org/employment...
# 9         10                           https://www.metlife.com/
#
#     id_idcd_plant                      MNAME  is_queried_search  \
# 0  06501600100000  DENVER SCHOOL DISTRICT 1                   1
# 1  06501600100000  DENVER SCHOOL DISTRICT 1                   1
# 2  06501600100000  DENVER SCHOOL DISTRICT 1                   1
# 3  06501600100000  DENVER SCHOOL DISTRICT 1                   1
# 4  06501600100000  DENVER SCHOOL DISTRICT 1                   1
# 5  06501600100000  DENVER SCHOOL DISTRICT 1                   1
# 6  06501600100000  DENVER SCHOOL DISTRICT 1                   1
# 7  06501600100000  DENVER SCHOOL DISTRICT 1                   1
# 8  06501600100000  DENVER SCHOOL DISTRICT 1                   1
# 9  06501600100000  DENVER SCHOOL DISTRICT 1                   1
#
#           date_queried_search
# 0  2022-08-17 14:01:55.247567
# 1  2022-08-17 14:01:55.247567
# 2  2022-08-17 14:01:55.247567
# 3  2022-08-17 14:01:55.247567
# 4  2022-08-17 14:01:55.247567
# 5  2022-08-17 14:01:55.247567
# 6  2022-08-17 14:01:55.247567
# 7  2022-08-17 14:01:55.247567
# 8  2022-08-17 14:01:55.247567
# 9  2022-08-17 14:01:55.247567

# %%
# from this I can see I want to pick the second row
new_start_url = google_urls.loc[google_urls['url_index']==2]['start_url'].values[0]
new_start_url
# Out:
# 'http://thecommons.dpsk12.org/Page/1397'

# %%
update = '''
         UPDATE gov_info
         SET start_url=?,
             is_scraped=0,
             num_scraped=0,
             pdf_count=0,
             sbc_count=0
         WHERE id_idcd_plant=?;
         '''

# %%
cur = dbconn.cursor()
cur.execute(update, (new_start_url, id_to_fix, ))
dbconn.commit()

# %%
cur.close()

# %% [markdown]
# #### Changelog for this manual process
# - Baltimore City changed to second Google url
# - BALTIMORE COUNTY PUBLIC SCHOOLS changed to fourth Google url
# - Community College of Baltimore City changed to fourth Google url
# - Memphis City changed to fourth Google url
# - Southeast Missouri State University changed to second Google url
# - Denver Public Schools changed to second Google url
